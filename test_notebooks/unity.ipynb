# %%
# !pip install torch torchvision
# !pip install pycocotools
# !pip install tqdm opencv-python

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from src.api import Detector

# %%
# weights can be downloaded from
# https://github.com/duanzhiihao/RAPiD/releases/download/v0.1/pL1_MWHB608_Mar11_4500.ckpt
detector = Detector(model_name='rapid',
                    weights_path='../weights/pL1_MWHB1024_Mar11_4000.ckpt',
                    use_cuda=True)
# Out:
# Using backbone Darknet-53. Loading ImageNet weights....
# Warning: no ImageNet-pretrained weights found. Please check https://github.com/duanzhiihao/RAPiD for it.
# Number of parameters in backbone: 40584928
# Successfully initialized model rapid. Total number of trainable parameters: 61523734
# Successfully loaded weights: ./weights/pL1_MWHB1024_Mar11_4000.ckpt
# Using CUDA...

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

def process_directory(img_dir, detector, input_size, conf_thres):
    # Liste des fichiers image
    image_files = [f for f in os.listdir(img_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    if not image_files:
        print("No images found in the directory.")
        return

    # Utiliser les dimensions de la première image
    first_image_path = os.path.join(img_dir, image_files[0])
    with Image.open(first_image_path) as img:
        max_width, max_height = img.size

    # Créer une seule figure et des axes
    fig, ax = plt.subplots()
    ax.imshow(Image.new('RGB', (max_width, max_height), (255, 255, 255)))  # Fond blanc
    ax.set_xlim([0, max_width])
    ax.set_ylim([max_height, 0])

    # Traiter chaque fichier image dans le répertoire
    for filename in image_files:
        img_path = os.path.join(img_dir, filename)
        print(f"Processing {img_path}...")

        detections = detector.detect_one(
            img_path=img_path, 
            input_size=input_size,
            conf_thres=conf_thres,
            return_img=False
        )
        
        # Ajouter les centres des détections sur le plan
        if detections is not None and detections.numel() > 0:
            for detection in detections:
                x, y, w, h, angle, conf = detection
                center_x, center_y = x + w / 2, y + h / 2
                ax.plot(center_x, center_y, 'ro')

    plt.title("Detection centers for all images")
    plt.show()
    print(detections)

# Configuration initiale, à adapter selon votre cas
detector = Detector(model_name='rapid', weights_path='./weights/pL1_MWHB1024_Mar11_4000.ckpt', use_cuda=True)
img_dir = './images/video_frames/'
input_size = 1024
conf_thres = 0.3

process_directory(img_dir, detector, input_size, conf_thres)
# Out:
# Using backbone Darknet-53. Loading ImageNet weights....
# Warning: no ImageNet-pretrained weights found. Please check https://github.com/duanzhiihao/RAPiD for it.
# Number of parameters in backbone: 40584928
# Successfully initialized model rapid. Total number of trainable parameters: 61523734
# Successfully loaded weights: ./weights/pL1_MWHB1024_Mar11_4000.ckpt
# Using CUDA...
# Processing ./images/video_frames/frame_0.jpg...
# Processing ./images/video_frames/frame_1.jpg...
# Processing ./images/video_frames/frame_10.jpg...
# Processing ./images/video_frames/frame_11.jpg...
# Processing ./images/video_frames/frame_12.jpg...
# Processing ./images/video_frames/frame_13.jpg...
# Processing ./images/video_frames/frame_14.jpg...
# Processing ./images/video_frames/frame_15.jpg...
# Processing ./images/video_frames/frame_16.jpg...
# Processing ./images/video_frames/frame_17.jpg...
# Processing ./images/video_frames/frame_18.jpg...
# Processing ./images/video_frames/frame_19.jpg...
# Processing ./images/video_frames/frame_2.jpg...
# Processing ./images/video_frames/frame_20.jpg...
# Processing ./images/video_frames/frame_21.jpg...
# Processing ./images/video_frames/frame_22.jpg...
# Processing ./images/video_frames/frame_23.jpg...
# Processing ./images/video_frames/frame_24.jpg...
# Processing ./images/video_frames/frame_25.jpg...
# Processing ./images/video_frames/frame_26.jpg...
# Processing ./images/video_frames/frame_27.jpg...
# Processing ./images/video_frames/frame_28.jpg...
# Processing ./images/video_frames/frame_29.jpg...
# Processing ./images/video_frames/frame_3.jpg...
# Processing ./images/video_frames/frame_30.jpg...
# Processing ./images/video_frames/frame_31.jpg...
# Processing ./images/video_frames/frame_32.jpg...
# Processing ./images/video_frames/frame_33.jpg...
# Processing ./images/video_frames/frame_34.jpg...
# Processing ./images/video_frames/frame_35.jpg...
# Processing ./images/video_frames/frame_36.jpg...
# Processing ./images/video_frames/frame_37.jpg...
# Processing ./images/video_frames/frame_38.jpg...
# Processing ./images/video_frames/frame_39.jpg...
# Processing ./images/video_frames/frame_4.jpg...
# Processing ./images/video_frames/frame_40.jpg...
# Processing ./images/video_frames/frame_41.jpg...
# Processing ./images/video_frames/frame_42.jpg...
# Processing ./images/video_frames/frame_43.jpg...
# Processing ./images/video_frames/frame_44.jpg...
# Processing ./images/video_frames/frame_45.jpg...
# Processing ./images/video_frames/frame_46.jpg...
# Processing ./images/video_frames/frame_47.jpg...
# Processing ./images/video_frames/frame_48.jpg...
# Processing ./images/video_frames/frame_49.jpg...
# Processing ./images/video_frames/frame_5.jpg...
# Processing ./images/video_frames/frame_50.jpg...
# Processing ./images/video_frames/frame_51.jpg...
# Processing ./images/video_frames/frame_52.jpg...
# Processing ./images/video_frames/frame_53.jpg...
# Processing ./images/video_frames/frame_54.jpg...
# Processing ./images/video_frames/frame_55.jpg...
# Processing ./images/video_frames/frame_56.jpg...
# Processing ./images/video_frames/frame_57.jpg...
# Processing ./images/video_frames/frame_58.jpg...
# Processing ./images/video_frames/frame_59.jpg...
# Processing ./images/video_frames/frame_6.jpg...
# Processing ./images/video_frames/frame_60.jpg...
# Processing ./images/video_frames/frame_61.jpg...
# Processing ./images/video_frames/frame_62.jpg...
# Processing ./images/video_frames/frame_7.jpg...
# Processing ./images/video_frames/frame_8.jpg...
# Processing ./images/video_frames/frame_9.jpg...
# tensor([[ 8.3297e+02,  8.7688e+02,  9.1973e+01,  2.0280e+02,  9.8671e+00,
#           9.9560e-01],
#         [ 8.8575e+02,  1.2674e+02,  1.0801e+02,  2.4812e+02, -1.6166e+00,
#           9.9356e-01],
#         [ 9.9416e+02,  8.6002e+02,  8.5286e+01,  1.1684e+02, -3.2070e+01,
#           9.7999e-01],
#         [ 7.3861e+02,  8.2859e+02,  8.5509e+01,  2.3129e+02,  1.5633e+01,
#           9.7678e-01],
#         [ 7.2766e+02,  2.2178e+02,  1.8589e+02,  2.6115e+02, -8.1189e+01,
#           8.2794e-01],
#         [ 1.0634e+03,  5.5174e+02,  9.0124e+01,  1.6968e+02,  1.0021e+02,
#           7.5019e-01],
#         [ 1.2162e+03,  6.4318e+02,  1.3734e+02,  2.9049e+02, -7.8979e+01,
#           5.7960e-01]])

# %%
detector.detect_imgSeq(img_dir='./images/sample2/', input_size=1024, conf_thres=0.3)
# Out:
# Using PIL.Image format
#   0%|          | 0/11 [00:00<?, ?it/s]
# 100%|██████████| 11/11 [00:02<00:00,  5.00it/s]
# [{'image_id': 'frame_0',
#   'bbox': [793.5656127929688,
#    861.2059326171875,
#    90.49591827392578,
#    213.26138305664062,
#    14.563690185546875],
#   'score': 0.9966567754745483,
#   'segmentation': []},
#  {'image_id': 'frame_0',
#   'bbox': [1072.763916015625,
#    363.3988342285156,
#    118.73170471191406,
#    225.66543579101562,
#    57.2506103515625],
#   'score': 0.9827636480331421,
#   'segmentation': []},
#  {'image_id': 'frame_0',
#   'bbox': [880.021728515625,
#    321.29498291015625,
#    235.349853515625,
#    309.5596923828125,
#    18.169021606445312],
#   'score': 0.9785738587379456,
#   'segmentation': []},
#  {'image_id': 'frame_0',
#   'bbox': [999.6655883789062,
#    712.7340698242188,
#    145.927978515625,
#    230.20738220214844,
#    -18.478744506835938],
#   'score': 0.9660441875457764,
#   'segmentation': []},
#  {'image_id': 'frame_0',
#   'bbox': [883.5707397460938,
#    84.39199829101562,
#    89.87162780761719,
#    170.07859802246094,
#    2.902862548828125],
#   'score': 0.9392904043197632,
#   'segmentation': []},
#  {'image_id': 'frame_0',
#   'bbox': [1220.20849609375,
#    647.4239501953125,
#    138.1711883544922,
#    296.7479248046875,
#    123.74984741210938],
#   'score': 0.6300101280212402,
#   'segmentation': []},
#  {'image_id': 'frame_0',
#   'bbox': [637.1484985351562,
#    608.0684204101562,
#    123.37300109863281,
#    169.74696350097656,
#    96.77676391601562],
#   'score': 0.5811617374420166,
#   'segmentation': []},
#  {'image_id': 'frame_1',
#   'bbox': [805.1851196289062,
#    864.8259887695312,
#    94.0956802368164,
#    217.5938262939453,
#    8.654571533203125],
#   'score': 0.9955612421035767,
#   'segmentation': []},
#  {'image_id': 'frame_1',
#   'bbox': [1089.3240966796875,
#    349.9356689453125,
#    122.08727264404297,
#    210.5392303466797,
#    38.5875244140625],
#   'score': 0.9918177127838135,
#   'segmentation': []},
#  {'image_id': 'frame_1',
#   'bbox': [996.7427368164062,
#    727.6975708007812,
#    145.6210174560547,
#    226.651611328125,
#    -8.109283447265625],
#   'score': 0.9909850358963013,
#   'segmentation': []},
#  {'image_id': 'frame_1',
#   'bbox': [939.0281982421875,
#    276.5751647949219,
#    174.05511474609375,
#    356.814697265625,
#    18.2972412109375],
#   'score': 0.9798868894577026,
#   'segmentation': []},
#  {'image_id': 'frame_1',
#   'bbox': [885.2232666015625,
#    103.57635498046875,
#    90.37500762939453,
#    202.9010467529297,
#    1.3142242431640625],
#   'score': 0.9441004395484924,
#   'segmentation': []},
#  {'image_id': 'frame_1',
#   'bbox': [1219.7822265625,
#    649.6105346679688,
#    139.9015350341797,
#    299.69842529296875,
#    -65.90274810791016],
#   'score': 0.5506763458251953,
#   'segmentation': []},
#  {'image_id': 'frame_1',
#   'bbox': [637.3948364257812,
#    610.0496215820312,
#    123.3813705444336,
#    165.365478515625,
#    94.86248779296875],
#   'score': 0.5225013494491577,
#   'segmentation': []},
#  {'image_id': 'frame_10',
#   'bbox': [885.85595703125,
#    129.38009643554688,
#    106.46807861328125,
#    249.36767578125,
#    -1.761627197265625],
#   'score': 0.9961168766021729,
#   'segmentation': []},
#  {'image_id': 'frame_10',
#   'bbox': [1005.2705078125,
#    733.6456298828125,
#    114.60240936279297,
#    225.4575653076172,
#    -6.7406005859375],
#   'score': 0.9937748908996582,
#   'segmentation': []},
#  {'image_id': 'frame_10',
#   'bbox': [800.182373046875,
#    860.3529663085938,
#    79.99734497070312,
#    216.4240264892578,
#    7.8571319580078125],
#   'score': 0.9831917881965637,
#   'segmentation': []},
#  {'image_id': 'frame_10',
#   'bbox': [767.0795288085938,
#    190.8674774169922,
#    143.43907165527344,
#    243.43649291992188,
#    -12.506393432617188],
#   'score': 0.9752970337867737,
#   'segmentation': []},
#  {'image_id': 'frame_10',
#   'bbox': [1218.921142578125,
#    644.3641967773438,
#    138.10943603515625,
#    292.30126953125,
#    -68.63581085205078],
#   'score': 0.8666210770606995,
#   'segmentation': []},
#  {'image_id': 'frame_10',
#   'bbox': [746.416259765625,
#    887.4368896484375,
#    64.03571319580078,
#    189.99400329589844,
#    12.775604248046875],
#   'score': 0.5818159580230713,
#   'segmentation': []},
#  {'image_id': 'frame_10',
#   'bbox': [987.2765502929688,
#    860.0530395507812,
#    79.30277252197266,
#    120.26155853271484,
#    -22.858657836914062],
#   'score': 0.5373497605323792,
#   'segmentation': []},
#  {'image_id': 'frame_2',
#   'bbox': [808.0616455078125,
#    874.3486328125,
#    97.21475219726562,
#    199.451171875,
#    6.826751708984375],
#   'score': 0.9937991499900818,
#   'segmentation': []},
#  {'image_id': 'frame_2',
#   'bbox': [889.7722778320312,
#    132.91265869140625,
#    105.1174087524414,
#    245.35446166992188,
#    -0.16717529296875],
#   'score': 0.992633044719696,
#   'segmentation': []},
#  {'image_id': 'frame_2',
#   'bbox': [1027.7933349609375,
#    670.0972290039062,
#    119.38526153564453,
#    218.5698699951172,
#    -42.54827880859375],
#   'score': 0.9915145635604858,
#   'segmentation': []},
#  {'image_id': 'frame_2',
#   'bbox': [998.148193359375,
#    309.6119079589844,
#    191.84901428222656,
#    301.2029113769531,
#    14.074005126953125],
#   'score': 0.9223178625106812,
#   'segmentation': []},
#  {'image_id': 'frame_2',
#   'bbox': [1222.211669921875,
#    648.532470703125,
#    139.722412109375,
#    282.362060546875,
#    -67.83110046386719],
#   'score': 0.8939675688743591,
#   'segmentation': []},
#  {'image_id': 'frame_3',
#   'bbox': [791.4597778320312,
#    862.961669921875,
#    109.19168853759766,
#    214.29843139648438,
#    16.420211791992188],
#   'score': 0.9976904392242432,
#   'segmentation': []},
#  {'image_id': 'frame_3',
#   'bbox': [887.3453369140625,
#    129.32012939453125,
#    105.84849548339844,
#    249.76046752929688,
#    -1.3407440185546875],
#   'score': 0.9947059750556946,
#   'segmentation': []},
#  {'image_id': 'frame_3',
#   'bbox': [1072.3773193359375,
#    514.8007202148438,
#    117.24909973144531,
#    166.2576141357422,
#    -69.31623840332031],
#   'score': 0.8928238749504089,
#   'segmentation': []},
#  {'image_id': 'frame_3',
#   'bbox': [1032.3638916015625,
#    310.53521728515625,
#    192.54405212402344,
#    271.1176452636719,
#    -95.91641998291016],
#   'score': 0.8889375925064087,
#   'segmentation': []},
#  {'image_id': 'frame_3',
#   'bbox': [877.8314208984375,
#    544.5818481445312,
#    94.49153137207031,
#    116.36404418945312,
#    -82.80887603759766],
#   'score': 0.8485877513885498,
#   'segmentation': []},
#  {'image_id': 'frame_3',
#   'bbox': [1032.533935546875,
#    681.0414428710938,
#    128.46038818359375,
#    186.01513671875,
#    -57.938995361328125],
#   'score': 0.7723498940467834,
#   'segmentation': []},
#  {'image_id': 'frame_3',
#   'bbox': [1222.8038330078125,
#    648.9173583984375,
#    141.58428955078125,
#    276.60125732421875,
#    -77.02661895751953],
#   'score': 0.734120786190033,
#   'segmentation': []},
#  {'image_id': 'frame_3',
#   'bbox': [643.8327026367188,
#    650.9390258789062,
#    115.44547271728516,
#    202.1654510498047,
#    23.791778564453125],
#   'score': 0.5941342711448669,
#   'segmentation': []},
#  {'image_id': 'frame_4',
#   'bbox': [818.66845703125,
#    886.663330078125,
#    89.02981567382812,
#    211.62664794921875,
#    5.3155975341796875],
#   'score': 0.9978427886962891,
#   'segmentation': []},
#  {'image_id': 'frame_4',
#   'bbox': [887.6911010742188,
#    133.34169006347656,
#    104.09003448486328,
#    250.33352661132812,
#    -0.418365478515625],
#   'score': 0.992875337600708,
#   'segmentation': []},
#  {'image_id': 'frame_4',
#   'bbox': [1116.48095703125,
#    334.98321533203125,
#    120.50233459472656,
#    218.30865478515625,
#    38.37640380859375],
#   'score': 0.9549682140350342,
#   'segmentation': []},
#  {'image_id': 'frame_4',
#   'bbox': [1221.74609375,
#    650.6123046875,
#    138.30235290527344,
#    285.21923828125,
#    -69.7625961303711],
#   'score': 0.8993098735809326,
#   'segmentation': []},
#  {'image_id': 'frame_4',
#   'bbox': [998.0914306640625,
#    672.584716796875,
#    115.44393920898438,
#    181.99520874023438,
#    -27.768295288085938],
#   'score': 0.8420737385749817,
#   'segmentation': []},
#  {'image_id': 'frame_4',
#   'bbox': [883.93359375,
#    557.449462890625,
#    121.87581634521484,
#    169.91554260253906,
#    -47.14662170410156],
#   'score': 0.5079057812690735,
#   'segmentation': []},
#  {'image_id': 'frame_4',
#   'bbox': [1272.6505126953125,
#    351.7735290527344,
#    47.871009826660156,
#    63.32178497314453,
#    92.82269287109375],
#   'score': 0.3570057451725006,
#   'segmentation': []},
#  {'image_id': 'frame_5',
#   'bbox': [999.7188720703125,
#    796.3195190429688,
#    116.19530487060547,
#    230.59983825683594,
#    -21.880020141601562],
#   'score': 0.9973341226577759,
#   'segmentation': []},
#  {'image_id': 'frame_5',
#   'bbox': [845.5343627929688,
#    876.2869262695312,
#    85.55289459228516,
#    202.3107452392578,
#    3.163909912109375],
#   'score': 0.9971334934234619,
#   'segmentation': []},
#  {'image_id': 'frame_5',
#   'bbox': [886.8780517578125,
#    128.73681640625,
#    105.94465637207031,
#    249.76187133789062,
#    -0.3044891357421875],
#   'score': 0.9954043626785278,
#   'segmentation': []},
#  {'image_id': 'frame_5',
#   'bbox': [1144.8427734375,
#    230.55935668945312,
#    119.572998046875,
#    202.94020080566406,
#    32.02154541015625],
#   'score': 0.9897326827049255,
#   'segmentation': []},
#  {'image_id': 'frame_5',
#   'bbox': [1036.34375,
#    457.69921875,
#    125.09831237792969,
#    182.89915466308594,
#    43.75495910644531],
#   'score': 0.9669577479362488,
#   'segmentation': []},
#  {'image_id': 'frame_5',
#   'bbox': [616.8223876953125,
#    714.0465698242188,
#    87.11834716796875,
#    189.41983032226562,
#    28.052749633789062],
#   'score': 0.7631920576095581,
#   'segmentation': []},
#  {'image_id': 'frame_5',
#   'bbox': [1221.27978515625,
#    646.400634765625,
#    142.1368865966797,
#    285.01873779296875,
#    -78.837646484375],
#   'score': 0.7512487173080444,
#   'segmentation': []},
#  {'image_id': 'frame_6',
#   'bbox': [885.203125,
#    845.3281860351562,
#    95.33362579345703,
#    202.7503204345703,
#    2.3876190185546875],
#   'score': 0.9954179525375366,
#   'segmentation': []},
#  {'image_id': 'frame_6',
#   'bbox': [887.2760009765625,
#    131.2244873046875,
#    105.19529724121094,
#    249.61538696289062,
#    -2.4433441162109375],
#   'score': 0.9946434497833252,
#   'segmentation': []},
#  {'image_id': 'frame_6',
#   'bbox': [1116.1480712890625,
#    214.8221435546875,
#    104.23818969726562,
#    229.9781036376953,
#    19.677520751953125],
#   'score': 0.9785454273223877,
#   'segmentation': []},
#  {'image_id': 'frame_6',
#   'bbox': [1035.0540771484375,
#    850.3399658203125,
#    89.59051513671875,
#    176.44290161132812,
#    -29.2371826171875],
#   'score': 0.9631749987602234,
#   'segmentation': []},
#  {'image_id': 'frame_6',
#   'bbox': [980.8528442382812,
#    293.3171691894531,
#    164.48233032226562,
#    200.16856384277344,
#    16.61181640625],
#   'score': 0.9361740350723267,
#   'segmentation': []},
#  {'image_id': 'frame_6',
#   'bbox': [620.80224609375,
#    725.8526000976562,
#    112.1434555053711,
#    180.76422119140625,
#    38.97651672363281],
#   'score': 0.9185577034950256,
#   'segmentation': []},
#  {'image_id': 'frame_6',
#   'bbox': [1220.8232421875,
#    647.497314453125,
#    140.51455688476562,
#    286.4533386230469,
#    -72.39544677734375],
#   'score': 0.8446343541145325,
#   'segmentation': []},
#  {'image_id': 'frame_7',
#   'bbox': [1071.977294921875,
#    235.9265899658203,
#    122.22235870361328,
#    212.6513671875,
#    20.955825805664062],
#   'score': 0.9960894584655762,
#   'segmentation': []},
#  {'image_id': 'frame_7',
#   'bbox': [935.0192260742188,
#    260.2740173339844,
#    110.18472290039062,
#    219.79127502441406,
#    3.741363525390625],
#   'score': 0.9877220988273621,
#   'segmentation': []},
#  {'image_id': 'frame_7',
#   'bbox': [873.1884155273438,
#    814.834228515625,
#    78.42704772949219,
#    199.54959106445312,
#    -0.6085205078125],
#   'score': 0.9726915955543518,
#   'segmentation': []},
#  {'image_id': 'frame_7',
#   'bbox': [885.6944580078125,
#    100.78685760498047,
#    91.82941436767578,
#    199.98419189453125,
#    1.841949462890625],
#   'score': 0.9485411047935486,
#   'segmentation': []},
#  {'image_id': 'frame_7',
#   'bbox': [642.2721557617188,
#    770.487060546875,
#    120.35984802246094,
#    193.32168579101562,
#    32.19792175292969],
#   'score': 0.8341320157051086,
#   'segmentation': []},
#  {'image_id': 'frame_7',
#   'bbox': [1221.37841796875,
#    642.8873291015625,
#    138.37864685058594,
#    286.81781005859375,
#    117.56649780273438],
#   'score': 0.7073603868484497,
#   'segmentation': []},
#  {'image_id': 'frame_8',
#   'bbox': [859.0703125,
#    848.1787109375,
#    87.39668273925781,
#    209.22911071777344,
#    -0.0381622314453125],
#   'score': 0.995776355266571,
#   'segmentation': []},
#  {'image_id': 'frame_8',
#   'bbox': [887.7448120117188,
#    129.53802490234375,
#    106.56684875488281,
#    244.61451721191406,
#    -4.3475341796875],
#   'score': 0.9872943758964539,
#   'segmentation': []},
#  {'image_id': 'frame_8',
#   'bbox': [698.3399658203125,
#    801.0253295898438,
#    125.04998779296875,
#    200.4641876220703,
#    16.6094970703125],
#   'score': 0.984276533126831,
#   'segmentation': []},
#  {'image_id': 'frame_8',
#   'bbox': [845.6986694335938,
#    221.4570770263672,
#    150.31564331054688,
#    228.1824951171875,
#    -12.727981567382812],
#   'score': 0.9605715274810791,
#   'segmentation': []},
#  {'image_id': 'frame_8',
#   'bbox': [1054.2347412109375,
#    366.7442626953125,
#    133.31459045410156,
#    191.3876190185547,
#    46.1773681640625],
#   'score': 0.9516725540161133,
#   'segmentation': []},
#  {'image_id': 'frame_8',
#   'bbox': [1022.9810791015625,
#    855.874755859375,
#    121.16432189941406,
#    158.5811004638672,
#    -39.2772216796875],
#   'score': 0.8997555375099182,
#   'segmentation': []},
#  {'image_id': 'frame_8',
#   'bbox': [1218.76318359375,
#    646.6836547851562,
#    139.44656372070312,
#    287.7292175292969,
#    -71.9237060546875],
#   'score': 0.8153972625732422,
#   'segmentation': []},
#  {'image_id': 'frame_9',
#   'bbox': [832.9736328125,
#    876.884765625,
#    91.97254943847656,
#    202.8032684326172,
#    9.867080688476562],
#   'score': 0.9956010580062866,
#   'segmentation': []},
#  {'image_id': 'frame_9',
#   'bbox': [885.748779296875,
#    126.73816680908203,
#    108.01165771484375,
#    248.1154327392578,
#    -1.6165618896484375],
#   'score': 0.9935606718063354,
#   'segmentation': []},
#  {'image_id': 'frame_9',
#   'bbox': [994.164306640625,
#    860.0180053710938,
#    85.28556823730469,
#    116.83544921875,
#    -32.06950378417969],
#   'score': 0.9799947142601013,
#   'segmentation': []},
#  {'image_id': 'frame_9',
#   'bbox': [738.6143798828125,
#    828.594482421875,
#    85.50933074951172,
#    231.29437255859375,
#    15.632583618164062],
#   'score': 0.9767795205116272,
#   'segmentation': []},
#  {'image_id': 'frame_9',
#   'bbox': [727.6641845703125,
#    221.7835235595703,
#    185.89231872558594,
#    261.1546936035156,
#    -81.18943786621094],
#   'score': 0.8279399275779724,
#   'segmentation': []},
#  {'image_id': 'frame_9',
#   'bbox': [1063.3902587890625,
#    551.7394409179688,
#    90.12446594238281,
#    169.68038940429688,
#    100.20730590820312],
#   'score': 0.7501924633979797,
#   'segmentation': []},
#  {'image_id': 'frame_9',
#   'bbox': [1216.2401123046875,
#    643.1768188476562,
#    137.3387451171875,
#    290.49267578125,
#    -78.97891235351562],
#   'score': 0.5796003341674805,
#   'segmentation': []}]
